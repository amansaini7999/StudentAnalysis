# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Analysis/Class1.csv")

# %%
df.logicalReasoning[0]*10
# Out:
# 25.0

# %%
for i in range(1):
    plt.bar(['Logical Reasoning','Science','Mathematics','Advance Section'],[df.logicalPercentile[i],df.sciencePercentile[i],df.mathematicsPercentile[i],df.advancePercentile[i]])
    ymin, ymax = 0, 100
    plt.ylim(ymin, ymax)
    plt.savefig("percentileScoreGraph/Class" + df.rollNumber[i][7:9] + "/" + df.rollNumber[i] + ".png", dpi = 200)
    plt.show()

    plt.plot(['Your Marks','School Average Marks','National Average Marks'],[df.marksObtained[i],df.schoolAverage[i],df.nationalAverage[i]], marker='.')
    ymin, ymax = -10, 40
    plt.ylim(ymin, ymax)
    plt.savefig("averageMarksGraph//Class" + df.rollNumber[i][7:9] + "/" + df.rollNumber[i] + ".png", dpi = 160)
    plt.show()

    plt.bar(['Logical Reasoning','Science','Mathematics','Advance Section'],[(df.logicalReasoning[i]*10),(df.Science[i]*10),(df.Mathematics[i]*10),(df.advanceSection[i]*10)])
    ymin, ymax = -25, 100
    plt.ylim(ymin, ymax)
    plt.savefig("topicWiseGraph/Class" + df.rollNumber[i][7:9] + "/" + df.rollNumber[i] + ".png", dpi = 170)
    plt.show()
