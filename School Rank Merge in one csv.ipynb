# %%
import pandas as pd
import os

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
path = "/home/aman/Documents/eurekaGurus/Dataset/Class Rank/"

# %%
files = []
for r,d,f in os.walk(path):
    for file in f:
        files.append(os.path.join(r, file))

# %%
df = pd.DataFrame(columns = ['Roll Number', 'Class Rank'])

# %%
for i in files:
    df1 = pd.read_csv(i)
    df = pd.concat([df, df1])

# %%
df = df.rename(columns = {'Roll Number' : 'Key', 'Class Rank':'School Rank'})
df = df.set_index('Key')
df = df.sort_index()
df
# Out:
#                School Rank
# Key
# C12001-01-0001           1
# C12001-01-0002           3
# C12001-01-0003          10
# C12001-01-0004           9
# C12001-01-0005           5
# C12001-01-0006           4
# C12001-01-0007           2
# C12001-01-0008           8
# C12001-01-0009           6
# C12001-01-0010           7
# C12002-01-0001           2
# C12002-01-0002           9
# C12002-01-0003           8
# C12002-01-0004          10
# C12002-01-0005           7
# C12002-01-0006           6
# C12002-01-0007           4
# C12002-01-0008           1
# C12002-01-0009           5
# C12002-01-0010           3
# C12003-01-0001           1
# C12003-01-0002           4
# C12003-01-0003           7
# C12003-01-0004           6
# C12003-01-0005           5
# C12003-01-0006          10
# C12003-01-0007           8
# C12003-01-0008           9
# C12003-01-0009           3
# C12003-01-0010           2
# C12004-01-0001           4
# C12004-01-0002           7
# C12004-01-0003           8
# ...

# %%
df.to_csv('/home/aman/Documents/eurekaGurus/Dataset/Class Rank/Class 1.csv')
